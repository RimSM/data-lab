# %%
from pyspark.sql import (
    functions as f, 
    SparkSession, 
    types as t
)

# %%
spark = SparkSession.builder.appName('df_join').getOrCreate()

# %%
user_data = [
    ["1000", "Neville Hardy", "Apple"],
    ["2000", "Dacia Cohen", "Alphabet"],
    ["3000", "Elois Cox", "Neflix"],
    ["4000", "Junita Meyer", "Meta"],
    ["5000", "Cleora Banks", "Amazon"]]

user_col = ['id', 'name', 'company']

df_user = spark.createDataFrame(data = user_data, schema = user_col)
df_user.show()
# Out:
# +----+-------------+--------+
# |  id|         name| company|
# +----+-------------+--------+
# |1000|Neville Hardy|   Apple|
# |2000|  Dacia Cohen|Alphabet|
# |3000|    Elois Cox|  Neflix|
# |4000| Junita Meyer|    Meta|
# |5000| Cleora Banks|  Amazon|
# +----+-------------+--------+

# %%
salary_data = [
    ["1000", "150000", "engineer"],
    ["2000", "240000", "manager"],
    ["3000", "120000", "human resource"],
    ["6000", "100000", "sales"]
]

salary_col = ['id', 'salary', 'department']

df_salary = spark.createDataFrame(data = salary_data, schema = salary_col)
df_salary.show()
# Out:
# +----+------+--------------+
# |  id|salary|    department|
# +----+------+--------------+
# |1000|150000|      engineer|
# |2000|240000|       manager|
# |3000|120000|human resource|
# |6000|100000|         sales|
# +----+------+--------------+

# %%
# inner join 
df_user.join(
    df_salary, 
    df_user.id == df_salary.id, 
    'inner'
).where(df_user.id == 1000).show()
# Out:
# +----+-------------+-------+----+------+----------+
# |  id|         name|company|  id|salary|department|
# +----+-------------+-------+----+------+----------+
# |1000|Neville Hardy|  Apple|1000|150000|  engineer|
# +----+-------------+-------+----+------+----------+

# %%
#multiple join 
df_user.join(
    df_salary, 
    (df_user.id == df_salary.id) & (df_user.id == 1000)
).show()
# Out:
# +----+-------------+-------+----+------+----------+
# |  id|         name|company|  id|salary|department|
# +----+-------------+-------+----+------+----------+
# |1000|Neville Hardy|  Apple|1000|150000|  engineer|
# +----+-------------+-------+----+------+----------+

# %%
# outer join 
df_user.join(
    df_salary, 
    df_user.id == df_salary.id, 
    'outer'
).show()
# Out:
# +----+-------------+--------+----+------+--------------+
# |  id|         name| company|  id|salary|    department|
# +----+-------------+--------+----+------+--------------+
# |1000|Neville Hardy|   Apple|1000|150000|      engineer|
# |2000|  Dacia Cohen|Alphabet|2000|240000|       manager|
# |3000|    Elois Cox|  Neflix|3000|120000|human resource|
# |4000| Junita Meyer|    Meta|NULL|  NULL|          NULL|
# |5000| Cleora Banks|  Amazon|NULL|  NULL|          NULL|
# |NULL|         NULL|    NULL|6000|100000|         sales|
# +----+-------------+--------+----+------+--------------+

# %%
# left join 
df_user.join(
    df_salary, 
    df_salary.id == df_salary.id, 
    'left'
).show()
# Out:
# +----+-------------+--------+----+------+--------------+
# |  id|         name| company|  id|salary|    department|
# +----+-------------+--------+----+------+--------------+
# |1000|Neville Hardy|   Apple|1000|150000|      engineer|
# |1000|Neville Hardy|   Apple|2000|240000|       manager|
# |1000|Neville Hardy|   Apple|3000|120000|human resource|
# |1000|Neville Hardy|   Apple|6000|100000|         sales|
# |2000|  Dacia Cohen|Alphabet|1000|150000|      engineer|
# |2000|  Dacia Cohen|Alphabet|2000|240000|       manager|
# |2000|  Dacia Cohen|Alphabet|3000|120000|human resource|
# |2000|  Dacia Cohen|Alphabet|6000|100000|         sales|
# |3000|    Elois Cox|  Neflix|1000|150000|      engineer|
# |3000|    Elois Cox|  Neflix|2000|240000|       manager|
# |3000|    Elois Cox|  Neflix|3000|120000|human resource|
# |3000|    Elois Cox|  Neflix|6000|100000|         sales|
# |4000| Junita Meyer|    Meta|1000|150000|      engineer|
# |4000| Junita Meyer|    Meta|2000|240000|       manager|
# |4000| Junita Meyer|    Meta|3000|120000|human resource|
# |4000| Junita Meyer|    Meta|6000|100000|         sales|
# |5000| Cleora Banks|  Amazon|1000|150000|      engineer|
# |5000| Cleora Banks|  Amazon|2000|240000|       manager|
# |5000| Cleora Banks|  Amazon|3000|120000|human resource|
# |5000| Cleora Banks|  Amazon|6000|100000|         sales|
# +----+-------------+--------+----+------+--------------+

# %%
# sql join 
df_user.createOrReplaceTempView('user')
df_salary.createOrReplaceTempView('salary')

spark.sql("""
    SELECT *
    FROM user u
    JOIN salary s ON u.id = s.id
""").show()
# Out:
# +----+-------------+--------+----+------+--------------+
# |  id|         name| company|  id|salary|    department|
# +----+-------------+--------+----+------+--------------+
# |1000|Neville Hardy|   Apple|1000|150000|      engineer|
# |2000|  Dacia Cohen|Alphabet|2000|240000|       manager|
# |3000|    Elois Cox|  Neflix|3000|120000|human resource|
# +----+-------------+--------+----+------+--------------+
